# %%
# Import Dependencies or Modules
import pandas as pd
import numpy as np
from citipy import citipy
import requests
import time

# Get the API key from the config.py file
from config import weather_key

# %%
# Create a new set of 2,000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
long = np.random.uniform(low=-180.000, high=180.000, size=2000)
lats_longs = zip(lats, long)

# %%
# Get the nearest city using the citipy module
# 1st I should add the lats_longs touples as a list of coordinates, then get the nearest city
coordinates = list(lats_longs)

# Create a City's list to hold all cities
cities = []

# Get the nearest city using the coordinate and add it to the city's list if not found
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # if not found, then add it to the City's list
    if city not in cities:
        cities.append(city)
        
# Print total number of cities that were added by printing the lenght of the list
print(f'Total number of cities is: {len(cities)}')
# Out:
# Total number of cities is: 767

# %%
# Perform an API call with the OpenWeatherMap

# 1 .- Create a variable to hold the URL we will use to get data using the WeatherMap API; I'm using imperial units
url = "https://api.openweathermap.org/data/2.5/weather?units=imperial&appid=" + weather_key

# 2 .- Create a list to hold city weather data
city_data = []

# Due to the limitation imposed by the API package we got that only allows 60 calls per minute, we'll do it in batches of 50 cities

# 3 .- Ceate counters
record_count = 1
set_count = 1

# 4 .- Start the API call process
print("-----------------------------")
print("Start Data Retrieval         ")
print("-----------------------------")

# Loop through all the cities
# For testing purposes only
# for i in range(15):
for i in range(len(cities)):

    
    # Create sets of 50 cities
    if (i % 50 == 0 and i >= 50):
        # reset counter, increase set_counter, then set record_counter to 1
        set_count += 1
        record_count = 1
        
        # to bypass API limitations, set a timer to 60 seconds
        print("------------------------------------------------------------------")
        print(f"Waiting 60 seconds...")
        print("------------------------------------------------------------------")
        time.sleep(60)
        
    # Set city URL
    city_url = url + "&q=" + cities[i].replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {cities[i]}")
    record_count += 1
    
    city_weather = requests.get(city_url).json()
        
    # Parse data
    # Enclose the API request within a try-except so we can process the entire list of cities regradless of any error
    try:
        # Request the City weather via the API using the url and the request.get fucntion, in a json format
        city_weather = requests.get(city_url).json()
        
        # Parse data
        city_name = city_weather["name"]
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_CurrentDescription = city_weather["weather"][0]["description"]
        
        # Add city to the city_data list
        # title() will set the first character of every world to upper case.
        city_data.append({"City": cities[i].title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,                          
                          "Current Description": city_CurrentDescription})
    
    except:
        # If an error occurred, show it, city name should be above based on previous message
        # pass vs. continue
        # pass: does nothing, it will skip the to the next loop cycle
        # continue: will continue execution therefore would try to set the city_lat regardless if the API call failed or not, potentially generating a different error
        print(f"City was not found. Skipping...")
        pass
          
print("-----------------------------")
print("Data Retrieval Completed     ")
print("-----------------------------")

print(f"Total number of cities that were pulled via the API: {len(city_data)}")
# Out:
# -----------------------------
# Start Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | east london
# Processing Record 2 of Set 1 | cabo san lucas
# Processing Record 3 of Set 1 | qaanaaq
# Processing Record 4 of Set 1 | pangnirtung
# Processing Record 5 of Set 1 | chuy
# Processing Record 6 of Set 1 | ciudad bolivar
# Processing Record 7 of Set 1 | renqiu
# Processing Record 8 of Set 1 | new norfolk
# Processing Record 9 of Set 1 | hanstholm
# Processing Record 10 of Set 1 | bethel
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | mar del plata
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | kapaa
# Processing Record 15 of Set 1 | hukuntsi
# Processing Record 16 of Set 1 | gamba
# Processing Record 17 of Set 1 | kijang
# Processing Record 18 of Set 1 | illoqqortoormiut
# City was not found. Skipping...
# Processing Record 19 of Set 1 | hilo
# Processing Record 20 of Set 1 | hasaki
# Processing Record 21 of Set 1 | saint-philippe
# Processing Record 22 of Set 1 | butaritari
# Processing Record 23 of Set 1 | kuito
# Processing Record 24 of Set 1 | bilibino
# Processing Record 25 of Set 1 | jamestown
# Processing Record 26 of Set 1 | ushtobe
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | taoudenni
# Processing Record 29 of Set 1 | kahului
# Processing Record 30 of Set 1 | busselton
# Processing Record 31 of Set 1 | leningradskiy
# Processing Record 32 of Set 1 | kavaratti
# Processing Record 33 of Set 1 | kanniyakumari
# Processing Record 34 of Set 1 | touros
# Processing Record 35 of Set 1 | grand river south east
# City was not found. Skipping...
# Processing Record 36 of Set 1 | saskylakh
# Processing Record 37 of Set 1 | verkhoyansk
# Processing Record 38 of Set 1 | tuggurt
# City was not found. Skipping...
# Processing Record 39 of Set 1 | carnarvon
# Processing Record 40 of Set 1 | yellowknife
# Processing Record 41 of Set 1 | arraial do cabo
# Processing Record 42 of Set 1 | bengkulu
# Processing Record 43 of Set 1 | thompson
# Processing Record 44 of Set 1 | warqla
# City was not found. Skipping...
# Processing Record 45 of Set 1 | puerto escondido
# Processing Record 46 of Set 1 | barrow
# Processing Record 47 of Set 1 | the valley
# Processing Record 48 of Set 1 | ust-omchug
# Processing Record 49 of Set 1 | sinaloa
# Processing Record 50 of Set 1 | rikitea
# ------------------------------------------------------------------
# Waiting 60 seconds...
# ------------------------------------------------------------------
# Processing Record 1 of Set 2 | ahuimanu
# Processing Record 2 of Set 2 | buala
# Processing Record 3 of Set 2 | meulaboh
# Processing Record 4 of Set 2 | vaitupu
# City was not found. Skipping...
# Processing Record 5 of Set 2 | nikolskoye
# Processing Record 6 of Set 2 | goderich
# Processing Record 7 of Set 2 | pangody
# Processing Record 8 of Set 2 | belaya gora
# Processing Record 9 of Set 2 | kodiak
# Processing Record 10 of Set 2 | longyearbyen
# Processing Record 11 of Set 2 | katsuura
# Processing Record 12 of Set 2 | rondonopolis
# Processing Record 13 of Set 2 | pahrump
# Processing Record 14 of Set 2 | eyl
# Processing Record 15 of Set 2 | coihaique
# Processing Record 16 of Set 2 | klaksvik
# Processing Record 17 of Set 2 | nizhneyansk
# City was not found. Skipping...
# Processing Record 18 of Set 2 | mount gambier
# Processing Record 19 of Set 2 | albany
# Processing Record 20 of Set 2 | hobart
# Processing Record 21 of Set 2 | henties bay
# Processing Record 22 of Set 2 | hermanus
# Processing Record 23 of Set 2 | havre-saint-pierre
# Processing Record 24 of Set 2 | umzimvubu
# City was not found. Skipping...
# Processing Record 25 of Set 2 | cherskiy
# Processing Record 26 of Set 2 | ribeira grande
# Processing Record 27 of Set 2 | avarua
# Processing Record 28 of Set 2 | puerto ayora
# Processing Record 29 of Set 2 | cape town
# Processing Record 30 of Set 2 | bandarbeyla
# Processing Record 31 of Set 2 | cidreira
# Processing Record 32 of Set 2 | tiksi
# Processing Record 33 of Set 2 | garoua
# Processing Record 34 of Set 2 | le port
# Processing Record 35 of Set 2 | atuona
# Processing Record 36 of Set 2 | victoria
# Processing Record 37 of Set 2 | kiunga
# Processing Record 38 of Set 2 | te anau
# Processing Record 39 of Set 2 | ji-parana
# City was not found. Skipping...
# Processing Record 40 of Set 2 | robertson
# Processing Record 41 of Set 2 | turbiv
# Processing Record 42 of Set 2 | zyryanka
# Processing Record 43 of Set 2 | marcona
# City was not found. Skipping...
# Processing Record 44 of Set 2 | gorontalo
# Processing Record 45 of Set 2 | whitecourt
# Processing Record 46 of Set 2 | north augusta
# Processing Record 47 of Set 2 | vaini
# Processing Record 48 of Set 2 | constitucion
# Processing Record 49 of Set 2 | port alfred
# Processing Record 50 of Set 2 | vallenar
# ------------------------------------------------------------------
# Waiting 60 seconds...
# ------------------------------------------------------------------
# Processing Record 1 of Set 3 | taolanaro
# City was not found. Skipping...
# Processing Record 2 of Set 3 | bowmore
# Processing Record 3 of Set 3 | belushya guba
# City was not found. Skipping...
# Processing Record 4 of Set 3 | dzaoudzi
# Processing Record 5 of Set 3 | pangoa
# Processing Record 6 of Set 3 | sabang
# Processing Record 7 of Set 3 | bathsheba
# Processing Record 8 of Set 3 | barentsburg
# City was not found. Skipping...
# Processing Record 9 of Set 3 | alofi
# Processing Record 10 of Set 3 | japura
# Processing Record 11 of Set 3 | abha
# Processing Record 12 of Set 3 | provideniya
# Processing Record 13 of Set 3 | salalah
# Processing Record 14 of Set 3 | phanat nikhom
# Processing Record 15 of Set 3 | saint-leu
# Processing Record 16 of Set 3 | broome
# Processing Record 17 of Set 3 | iisalmi
# Processing Record 18 of Set 3 | laguna
# Processing Record 19 of Set 3 | kazalinsk
# City was not found. Skipping...
# Processing Record 20 of Set 3 | lyudinovo
# Processing Record 21 of Set 3 | sur
# Processing Record 22 of Set 3 | mayo
# Processing Record 23 of Set 3 | sobolevo
# Processing Record 24 of Set 3 | luderitz
# Processing Record 25 of Set 3 | kirkland lake
# Processing Record 26 of Set 3 | upernavik
# Processing Record 27 of Set 3 | puksoozero
# Processing Record 28 of Set 3 | fort nelson
# Processing Record 29 of Set 3 | haines junction
# Processing Record 30 of Set 3 | kavieng
# Processing Record 31 of Set 3 | husavik
# Processing Record 32 of Set 3 | walvis bay
# Processing Record 33 of Set 3 | torbay
# Processing Record 34 of Set 3 | namatanai
# Processing Record 35 of Set 3 | na wa
# Processing Record 36 of Set 3 | tessalit
# Processing Record 37 of Set 3 | georgetown
# Processing Record 38 of Set 3 | verkhnyaya inta
# Processing Record 39 of Set 3 | sitka
# Processing Record 40 of Set 3 | sentyabrskiy
# City was not found. Skipping...
# Processing Record 41 of Set 3 | leh
# Processing Record 42 of Set 3 | mach
# Processing Record 43 of Set 3 | lugovskiy
# City was not found. Skipping...
# Processing Record 44 of Set 3 | bredasdorp
# Processing Record 45 of Set 3 | mirabad
# Processing Record 46 of Set 3 | sao filipe
# Processing Record 47 of Set 3 | olafsvik
# Processing Record 48 of Set 3 | mahebourg
# Processing Record 49 of Set 3 | caravelas
# Processing Record 50 of Set 3 | takhtamygda
# ------------------------------------------------------------------
# Waiting 60 seconds...
# ------------------------------------------------------------------
# Processing Record 1 of Set 4 | fukue
# Processing Record 2 of Set 4 | hihifo
# City was not found. Skipping...
# Processing Record 3 of Set 4 | xichang
# Processing Record 4 of Set 4 | kidal
# Processing Record 5 of Set 4 | florida
# Processing Record 6 of Set 4 | kyaikkami
# Processing Record 7 of Set 4 | faanui
# Processing Record 8 of Set 4 | esperance
# Processing Record 9 of Set 4 | fort saint james
# Processing Record 10 of Set 4 | lazaro cardenas
# Processing Record 11 of Set 4 | geraldton
# Processing Record 12 of Set 4 | dikson
# Processing Record 13 of Set 4 | isangel
# Processing Record 14 of Set 4 | lebu
# Processing Record 15 of Set 4 | komsomolskiy
# Processing Record 16 of Set 4 | clyde river
# Processing Record 17 of Set 4 | saint george
# Processing Record 18 of Set 4 | pacific grove
# Processing Record 19 of Set 4 | tumannyy
# City was not found. Skipping...
# Processing Record 20 of Set 4 | baneh
# Processing Record 21 of Set 4 | pemba
# Processing Record 22 of Set 4 | barbar
# City was not found. Skipping...
# Processing Record 23 of Set 4 | tocopilla
# Processing Record 24 of Set 4 | banjar
# Processing Record 25 of Set 4 | kayerkan
# Processing Record 26 of Set 4 | ancud
# Processing Record 27 of Set 4 | ponta do sol
# Processing Record 28 of Set 4 | severo-kurilsk
# Processing Record 29 of Set 4 | ust-nera
# Processing Record 30 of Set 4 | mahadday weyne
# City was not found. Skipping...
# Processing Record 31 of Set 4 | desaguadero
# Processing Record 32 of Set 4 | tuktoyaktuk
# Processing Record 33 of Set 4 | tuatapere
# Processing Record 34 of Set 4 | saldanha
# Processing Record 35 of Set 4 | sotnikovo
# Processing Record 36 of Set 4 | toledo
# Processing Record 37 of Set 4 | sumbe
# Processing Record 38 of Set 4 | lincoln
# Processing Record 39 of Set 4 | khatanga
# Processing Record 40 of Set 4 | seoul
# Processing Record 41 of Set 4 | cabedelo
# Processing Record 42 of Set 4 | araouane
# Processing Record 43 of Set 4 | berlevag
# Processing Record 44 of Set 4 | hithadhoo
# Processing Record 45 of Set 4 | gasa
# Processing Record 46 of Set 4 | castro
# Processing Record 47 of Set 4 | ketchikan
# Processing Record 48 of Set 4 | mabaruma
# Processing Record 49 of Set 4 | harper
# Processing Record 50 of Set 4 | sao joao del rei
# ------------------------------------------------------------------
# Waiting 60 seconds...
# ------------------------------------------------------------------
# Processing Record 1 of Set 5 | amderma
# City was not found. Skipping...
# Processing Record 2 of Set 5 | haapiti
# Processing Record 3 of Set 5 | lorengau
# Processing Record 4 of Set 5 | bluff
# Processing Record 5 of Set 5 | paramonga
# Processing Record 6 of Set 5 | port elizabeth
# Processing Record 7 of Set 5 | hegang
# Processing Record 8 of Set 5 | jumla
# Processing Record 9 of Set 5 | astaneh-ye ashrafiyeh
# Processing Record 10 of Set 5 | doha
# Processing Record 11 of Set 5 | samusu
# City was not found. Skipping...
# Processing Record 12 of Set 5 | livingston
# Processing Record 13 of Set 5 | guerrero negro
# Processing Record 14 of Set 5 | chernyshevskiy
# Processing Record 15 of Set 5 | avera
# Processing Record 16 of Set 5 | meadow lake
# Processing Record 17 of Set 5 | hobyo
# Processing Record 18 of Set 5 | alotau
# City was not found. Skipping...
# Processing Record 19 of Set 5 | port macquarie
# Processing Record 20 of Set 5 | kitimat
# Processing Record 21 of Set 5 | tra vinh
# Processing Record 22 of Set 5 | huarmey
# Processing Record 23 of Set 5 | kaitangata
# Processing Record 24 of Set 5 | camabatela
# Processing Record 25 of Set 5 | haimen
# Processing Record 26 of Set 5 | codrington
# Processing Record 27 of Set 5 | durban
# Processing Record 28 of Set 5 | lebork
# Processing Record 29 of Set 5 | harlingen
# Processing Record 30 of Set 5 | pumiao
# Processing Record 31 of Set 5 | halifax
# Processing Record 32 of Set 5 | stafford
# Processing Record 33 of Set 5 | coahuayana
# Processing Record 34 of Set 5 | muli
# Processing Record 35 of Set 5 | acari
# Processing Record 36 of Set 5 | arrecife
# Processing Record 37 of Set 5 | axim
# Processing Record 38 of Set 5 | saint anthony
# Processing Record 39 of Set 5 | ayan
# Processing Record 40 of Set 5 | richards bay
# Processing Record 41 of Set 5 | nauta
# Processing Record 42 of Set 5 | artyk
# City was not found. Skipping...
# Processing Record 43 of Set 5 | chokurdakh
# Processing Record 44 of Set 5 | shumskiy
# Processing Record 45 of Set 5 | bolshaya martynovka
# Processing Record 46 of Set 5 | la ronge
# Processing Record 47 of Set 5 | uthal
# Processing Record 48 of Set 5 | dera bugti
# Processing Record 49 of Set 5 | aklavik
# Processing Record 50 of Set 5 | talara
# ------------------------------------------------------------------
# Waiting 60 seconds...
# ------------------------------------------------------------------
# Processing Record 1 of Set 6 | kamenskoye
# City was not found. Skipping...
# Processing Record 2 of Set 6 | tilichiki
# Processing Record 3 of Set 6 | villa del rosario
# Processing Record 4 of Set 6 | kautokeino
# Processing Record 5 of Set 6 | safaga
# Processing Record 6 of Set 6 | rolim de moura
# City was not found. Skipping...
# Processing Record 7 of Set 6 | qui nhon
# Processing Record 8 of Set 6 | almenara
# Processing Record 9 of Set 6 | bosanski novi
# Processing Record 10 of Set 6 | beira
# Processing Record 11 of Set 6 | sao joao da barra
# Processing Record 12 of Set 6 | dedza
# Processing Record 13 of Set 6 | kruisfontein
# Processing Record 14 of Set 6 | lompoc
# Processing Record 15 of Set 6 | henderson
# Processing Record 16 of Set 6 | eirunepe
# Processing Record 17 of Set 6 | ravar
# Processing Record 18 of Set 6 | airai
# Processing Record 19 of Set 6 | port lincoln
# Processing Record 20 of Set 6 | kurilsk
# Processing Record 21 of Set 6 | sidi bu zayd
# City was not found. Skipping...
# Processing Record 22 of Set 6 | bang saphan
# Processing Record 23 of Set 6 | oranjestad
# Processing Record 24 of Set 6 | grand gaube
# Processing Record 25 of Set 6 | zeya
# Processing Record 26 of Set 6 | shingu
# Processing Record 27 of Set 6 | mys shmidta
# City was not found. Skipping...
# Processing Record 28 of Set 6 | pisco
# Processing Record 29 of Set 6 | osakarovka
# Processing Record 30 of Set 6 | vila velha
# Processing Record 31 of Set 6 | zaysan
# Processing Record 32 of Set 6 | iqaluit
# Processing Record 33 of Set 6 | korla
# Processing Record 34 of Set 6 | konevo
# Processing Record 35 of Set 6 | nishihara
# Processing Record 36 of Set 6 | rubi
# Processing Record 37 of Set 6 | don benito
# Processing Record 38 of Set 6 | olinda
# Processing Record 39 of Set 6 | greer
# Processing Record 40 of Set 6 | rokiskis
# Processing Record 41 of Set 6 | igra
# Processing Record 42 of Set 6 | ormara
# Processing Record 43 of Set 6 | vestmannaeyjar
# Processing Record 44 of Set 6 | san patricio
# Processing Record 45 of Set 6 | san jose
# Processing Record 46 of Set 6 | marfino
# Processing Record 47 of Set 6 | deputatskiy
# Processing Record 48 of Set 6 | rio blanco
# Processing Record 49 of Set 6 | nynashamn
# Processing Record 50 of Set 6 | merauke
# ------------------------------------------------------------------
# Waiting 60 seconds...
# ------------------------------------------------------------------
# Processing Record 1 of Set 7 | capreol
# Processing Record 2 of Set 7 | vestmanna
# Processing Record 3 of Set 7 | olga
# Processing Record 4 of Set 7 | tulare
# Processing Record 5 of Set 7 | vagur
# Processing Record 6 of Set 7 | pevek
# Processing Record 7 of Set 7 | winslow
# Processing Record 8 of Set 7 | santiago del estero
# Processing Record 9 of Set 7 | aguimes
# Processing Record 10 of Set 7 | charters towers
# Processing Record 11 of Set 7 | praia da vitoria
# Processing Record 12 of Set 7 | los llanos de aridane
# Processing Record 13 of Set 7 | alice springs
# Processing Record 14 of Set 7 | norman wells
# Processing Record 15 of Set 7 | alyangula
# Processing Record 16 of Set 7 | sabha
# Processing Record 17 of Set 7 | ahipara
# Processing Record 18 of Set 7 | teeli
# Processing Record 19 of Set 7 | biltine
# Processing Record 20 of Set 7 | kolaras
# Processing Record 21 of Set 7 | kirakira
# Processing Record 22 of Set 7 | paamiut
# Processing Record 23 of Set 7 | darlowo
# Processing Record 24 of Set 7 | dzhusaly
# City was not found. Skipping...
# Processing Record 25 of Set 7 | carballo
# Processing Record 26 of Set 7 | borogontsy
# Processing Record 27 of Set 7 | blythe
# Processing Record 28 of Set 7 | asau
# Processing Record 29 of Set 7 | quthing
# Processing Record 30 of Set 7 | ternate
# Processing Record 31 of Set 7 | cockburn town
# Processing Record 32 of Set 7 | san quintin
# Processing Record 33 of Set 7 | vardo
# Processing Record 34 of Set 7 | tayu
# Processing Record 35 of Set 7 | attawapiskat
# City was not found. Skipping...
# Processing Record 36 of Set 7 | vostok
# Processing Record 37 of Set 7 | nemuro
# Processing Record 38 of Set 7 | necochea
# Processing Record 39 of Set 7 | moron
# Processing Record 40 of Set 7 | ust-ilimsk
# Processing Record 41 of Set 7 | bayan
# Processing Record 42 of Set 7 | tazovskiy
# Processing Record 43 of Set 7 | methala
# Processing Record 44 of Set 7 | mizan teferi
# Processing Record 45 of Set 7 | ponca city
# Processing Record 46 of Set 7 | bambous virieux
# Processing Record 47 of Set 7 | flin flon
# Processing Record 48 of Set 7 | lata
# Processing Record 49 of Set 7 | pontes e lacerda
# Processing Record 50 of Set 7 | zheleznodorozhnyy
# ------------------------------------------------------------------
# Waiting 60 seconds...
# ------------------------------------------------------------------
# Processing Record 1 of Set 8 | tiarei
# Processing Record 2 of Set 8 | dingle
# Processing Record 3 of Set 8 | akhtubinsk
# Processing Record 4 of Set 8 | pasni
# Processing Record 5 of Set 8 | amur
# Processing Record 6 of Set 8 | smolenka
# Processing Record 7 of Set 8 | nguiu
# City was not found. Skipping...
# Processing Record 8 of Set 8 | lichinga
# Processing Record 9 of Set 8 | pitimbu
# Processing Record 10 of Set 8 | cape coast
# Processing Record 11 of Set 8 | pogar
# Processing Record 12 of Set 8 | arlit
# Processing Record 13 of Set 8 | bur gabo
# City was not found. Skipping...
# Processing Record 14 of Set 8 | skibbereen
# Processing Record 15 of Set 8 | bantry
# Processing Record 16 of Set 8 | dwarka
# Processing Record 17 of Set 8 | bundaberg
# Processing Record 18 of Set 8 | nouadhibou
# Processing Record 19 of Set 8 | sioux lookout
# Processing Record 20 of Set 8 | agirish
# Processing Record 21 of Set 8 | adrar
# Processing Record 22 of Set 8 | rocha
# Processing Record 23 of Set 8 | tezu
# Processing Record 24 of Set 8 | smithers
# Processing Record 25 of Set 8 | milkovo
# Processing Record 26 of Set 8 | lamesa
# Processing Record 27 of Set 8 | kardla
# Processing Record 28 of Set 8 | lingyuan
# Processing Record 29 of Set 8 | beringovskiy
# Processing Record 30 of Set 8 | binghamton
# Processing Record 31 of Set 8 | marivan
# Processing Record 32 of Set 8 | oranjemund
# Processing Record 33 of Set 8 | waipawa
# Processing Record 34 of Set 8 | bargal
# City was not found. Skipping...
# Processing Record 35 of Set 8 | port hardy
# Processing Record 36 of Set 8 | esqueda
# Processing Record 37 of Set 8 | hamilton
# Processing Record 38 of Set 8 | grand-santi
# Processing Record 39 of Set 8 | xining
# Processing Record 40 of Set 8 | ust-barguzin
# Processing Record 41 of Set 8 | muros
# Processing Record 42 of Set 8 | lander
# Processing Record 43 of Set 8 | mayumba
# Processing Record 44 of Set 8 | kloulklubed
# Processing Record 45 of Set 8 | tevaitoa
# Processing Record 46 of Set 8 | lavrentiya
# Processing Record 47 of Set 8 | atar
# Processing Record 48 of Set 8 | lolua
# City was not found. Skipping...
# Processing Record 49 of Set 8 | neiafu
# Processing Record 50 of Set 8 | yekimovichi
# ------------------------------------------------------------------
# Waiting 60 seconds...
# ------------------------------------------------------------------
# Processing Record 1 of Set 9 | stralsund
# Processing Record 2 of Set 9 | tsihombe
# City was not found. Skipping...
# Processing Record 3 of Set 9 | ipixuna
# Processing Record 4 of Set 9 | forest
# Processing Record 5 of Set 9 | payo
# Processing Record 6 of Set 9 | yerbogachen
# Processing Record 7 of Set 9 | kuching
# Processing Record 8 of Set 9 | marsh harbour
# Processing Record 9 of Set 9 | bozoum
# Processing Record 10 of Set 9 | san rafael
# Processing Record 11 of Set 9 | moose factory
# Processing Record 12 of Set 9 | san policarpo
# Processing Record 13 of Set 9 | catio
# Processing Record 14 of Set 9 | warrnambool
# Processing Record 15 of Set 9 | karkaralinsk
# City was not found. Skipping...
# Processing Record 16 of Set 9 | palabuhanratu
# City was not found. Skipping...
# Processing Record 17 of Set 9 | rostovka
# Processing Record 18 of Set 9 | butte
# Processing Record 19 of Set 9 | belle fourche
# Processing Record 20 of Set 9 | buraydah
# Processing Record 21 of Set 9 | salinas
# Processing Record 22 of Set 9 | mbaiki
# Processing Record 23 of Set 9 | novopavlovka
# Processing Record 24 of Set 9 | nurota
# Processing Record 25 of Set 9 | waingapu
# Processing Record 26 of Set 9 | belmonte
# Processing Record 27 of Set 9 | angangxi
# City was not found. Skipping...
# Processing Record 28 of Set 9 | kulu
# Processing Record 29 of Set 9 | saint-augustin
# Processing Record 30 of Set 9 | la ciotat
# Processing Record 31 of Set 9 | souris
# Processing Record 32 of Set 9 | galiwinku
# City was not found. Skipping...
# Processing Record 33 of Set 9 | pimentel
# Processing Record 34 of Set 9 | port hedland
# Processing Record 35 of Set 9 | nalut
# Processing Record 36 of Set 9 | mapiripan
# Processing Record 37 of Set 9 | kaeng khlo
# City was not found. Skipping...
# Processing Record 38 of Set 9 | erzin
# Processing Record 39 of Set 9 | akdepe
# Processing Record 40 of Set 9 | harare
# Processing Record 41 of Set 9 | sibenik
# Processing Record 42 of Set 9 | den helder
# Processing Record 43 of Set 9 | uberlandia
# Processing Record 44 of Set 9 | faya
# Processing Record 45 of Set 9 | lagoa
# Processing Record 46 of Set 9 | khani
# Processing Record 47 of Set 9 | bahia blanca
# Processing Record 48 of Set 9 | purranque
# Processing Record 49 of Set 9 | monaragala
# Processing Record 50 of Set 9 | hallingby
# City was not found. Skipping...
# ------------------------------------------------------------------
# Waiting 60 seconds...
# ------------------------------------------------------------------
# Processing Record 1 of Set 10 | prince rupert
# Processing Record 2 of Set 10 | the pas
# Processing Record 3 of Set 10 | hofn
# Processing Record 4 of Set 10 | dunedin
# Processing Record 5 of Set 10 | anadyr
# Processing Record 6 of Set 10 | noto
# Processing Record 7 of Set 10 | mutsamudu
# City was not found. Skipping...
# Processing Record 8 of Set 10 | buenos aires
# Processing Record 9 of Set 10 | terra santa
# Processing Record 10 of Set 10 | polson
# Processing Record 11 of Set 10 | kamaishi
# Processing Record 12 of Set 10 | mahina
# Processing Record 13 of Set 10 | ilo
# Processing Record 14 of Set 10 | tomatlan
# Processing Record 15 of Set 10 | pontianak
# Processing Record 16 of Set 10 | waspan
# Processing Record 17 of Set 10 | nyurba
# Processing Record 18 of Set 10 | ambilobe
# Processing Record 19 of Set 10 | bage
# Processing Record 20 of Set 10 | kyshtovka
# Processing Record 21 of Set 10 | honiara
# Processing Record 22 of Set 10 | dondo
# Processing Record 23 of Set 10 | fortuna
# Processing Record 24 of Set 10 | general roca
# Processing Record 25 of Set 10 | nuuk
# Processing Record 26 of Set 10 | capitan bado
# Processing Record 27 of Set 10 | samarai
# Processing Record 28 of Set 10 | mangai
# Processing Record 29 of Set 10 | tasiilaq
# Processing Record 30 of Set 10 | nanortalik
# Processing Record 31 of Set 10 | najran
# Processing Record 32 of Set 10 | newport
# Processing Record 33 of Set 10 | bubaque
# Processing Record 34 of Set 10 | muscat
# Processing Record 35 of Set 10 | yatou
# Processing Record 36 of Set 10 | launceston
# Processing Record 37 of Set 10 | tselinnoye
# Processing Record 38 of Set 10 | gazli
# Processing Record 39 of Set 10 | quang ngai
# Processing Record 40 of Set 10 | bintulu
# Processing Record 41 of Set 10 | lufilufi
# Processing Record 42 of Set 10 | oudtshoorn
# Processing Record 43 of Set 10 | salym
# Processing Record 44 of Set 10 | nabire
# Processing Record 45 of Set 10 | carroll
# Processing Record 46 of Set 10 | palmer
# Processing Record 47 of Set 10 | jinchang
# Processing Record 48 of Set 10 | marovoay
# Processing Record 49 of Set 10 | kingaroy
# Processing Record 50 of Set 10 | sedro-woolley
# ------------------------------------------------------------------
# Waiting 60 seconds...
# ------------------------------------------------------------------
# Processing Record 1 of Set 11 | narasannapeta
# Processing Record 2 of Set 11 | onguday
# Processing Record 3 of Set 11 | mutoko
# Processing Record 4 of Set 11 | ainazi
# Processing Record 5 of Set 11 | gravdal
# Processing Record 6 of Set 11 | gondanglegi
# Processing Record 7 of Set 11 | soller
# Processing Record 8 of Set 11 | san felipe
# Processing Record 9 of Set 11 | ojinaga
# Processing Record 10 of Set 11 | linares
# Processing Record 11 of Set 11 | traiguen
# Processing Record 12 of Set 11 | kaeo
# Processing Record 13 of Set 11 | fevralsk
# City was not found. Skipping...
# Processing Record 14 of Set 11 | viedma
# Processing Record 15 of Set 11 | westfield
# Processing Record 16 of Set 11 | namibe
# Processing Record 17 of Set 11 | acapulco
# Processing Record 18 of Set 11 | langsa
# Processing Record 19 of Set 11 | emba
# Processing Record 20 of Set 11 | satitoa
# City was not found. Skipping...
# Processing Record 21 of Set 11 | baltoji voke
# Processing Record 22 of Set 11 | rungata
# City was not found. Skipping...
# Processing Record 23 of Set 11 | aguililla
# Processing Record 24 of Set 11 | narsaq
# Processing Record 25 of Set 11 | sao felix do xingu
# Processing Record 26 of Set 11 | kupang
# Processing Record 27 of Set 11 | howard springs
# Processing Record 28 of Set 11 | changji
# Processing Record 29 of Set 11 | catumbela
# Processing Record 30 of Set 11 | churapcha
# Processing Record 31 of Set 11 | menongue
# Processing Record 32 of Set 11 | kenora
# Processing Record 33 of Set 11 | carutapera
# Processing Record 34 of Set 11 | lethem
# Processing Record 35 of Set 11 | la primavera
# Processing Record 36 of Set 11 | betioky
# Processing Record 37 of Set 11 | santa marta
# Processing Record 38 of Set 11 | prainha
# Processing Record 39 of Set 11 | shimoda
# Processing Record 40 of Set 11 | padang
# Processing Record 41 of Set 11 | fairbanks
# Processing Record 42 of Set 11 | loandjili
# Processing Record 43 of Set 11 | ambovombe
# Processing Record 44 of Set 11 | san jeronimo
# Processing Record 45 of Set 11 | gigmoto
# Processing Record 46 of Set 11 | ituni
# City was not found. Skipping...
# Processing Record 47 of Set 11 | sidi ali
# Processing Record 48 of Set 11 | rizhao
# Processing Record 49 of Set 11 | bridlington
# Processing Record 50 of Set 11 | praia
# ------------------------------------------------------------------
# Waiting 60 seconds...
# ------------------------------------------------------------------
# Processing Record 1 of Set 12 | iquitos
# Processing Record 2 of Set 12 | mehamn
# Processing Record 3 of Set 12 | caldas da rainha
# Processing Record 4 of Set 12 | poya
# Processing Record 5 of Set 12 | garm
# City was not found. Skipping...
# Processing Record 6 of Set 12 | souillac
# Processing Record 7 of Set 12 | ilulissat
# Processing Record 8 of Set 12 | pauini
# Processing Record 9 of Set 12 | severnoye
# Processing Record 10 of Set 12 | baiyin
# Processing Record 11 of Set 12 | port shepstone
# Processing Record 12 of Set 12 | gumla
# Processing Record 13 of Set 12 | mount isa
# Processing Record 14 of Set 12 | erenhot
# Processing Record 15 of Set 12 | coruripe
# Processing Record 16 of Set 12 | san cristobal
# Processing Record 17 of Set 12 | unnao
# Processing Record 18 of Set 12 | marystown
# Processing Record 19 of Set 12 | kiama
# Processing Record 20 of Set 12 | saleaula
# City was not found. Skipping...
# Processing Record 21 of Set 12 | troitsko-pechorsk
# Processing Record 22 of Set 12 | pombas
# Processing Record 23 of Set 12 | marawi
# Processing Record 24 of Set 12 | warrington
# Processing Record 25 of Set 12 | veraval
# Processing Record 26 of Set 12 | ananindeua
# Processing Record 27 of Set 12 | mehran
# Processing Record 28 of Set 12 | kachiry
# Processing Record 29 of Set 12 | guozhen
# Processing Record 30 of Set 12 | hirado
# Processing Record 31 of Set 12 | were ilu
# Processing Record 32 of Set 12 | stornoway
# Processing Record 33 of Set 12 | araguacu
# Processing Record 34 of Set 12 | vilhena
# Processing Record 35 of Set 12 | yasnyy
# Processing Record 36 of Set 12 | vila franca do campo
# Processing Record 37 of Set 12 | lasa
# Processing Record 38 of Set 12 | malindi
# Processing Record 39 of Set 12 | superior
# Processing Record 40 of Set 12 | christchurch
# Processing Record 41 of Set 12 | linxia
# Processing Record 42 of Set 12 | shediac
# Processing Record 43 of Set 12 | bratsk
# Processing Record 44 of Set 12 | jaisalmer
# Processing Record 45 of Set 12 | newton stewart
# Processing Record 46 of Set 12 | picos
# Processing Record 47 of Set 12 | tura
# Processing Record 48 of Set 12 | sorland
# Processing Record 49 of Set 12 | santa cruz
# Processing Record 50 of Set 12 | kalmunai
# ------------------------------------------------------------------
# Waiting 60 seconds...
# ------------------------------------------------------------------
# Processing Record 1 of Set 13 | okha
# Processing Record 2 of Set 13 | santa isabel do rio negro
# Processing Record 3 of Set 13 | sakskobing
# Processing Record 4 of Set 13 | itupiranga
# Processing Record 5 of Set 13 | mentok
# City was not found. Skipping...
# Processing Record 6 of Set 13 | katha
# City was not found. Skipping...
# Processing Record 7 of Set 13 | tongzhou
# Processing Record 8 of Set 13 | bull savanna
# Processing Record 9 of Set 13 | semnan
# Processing Record 10 of Set 13 | tagusao
# Processing Record 11 of Set 13 | pacifica
# Processing Record 12 of Set 13 | luena
# Processing Record 13 of Set 13 | tanete
# Processing Record 14 of Set 13 | oksfjord
# Processing Record 15 of Set 13 | homer
# Processing Record 16 of Set 13 | lomovka
# Processing Record 17 of Set 13 | olavarria
# Processing Record 18 of Set 13 | bairnsdale
# Processing Record 19 of Set 13 | paita
# Processing Record 20 of Set 13 | baykit
# Processing Record 21 of Set 13 | nara
# Processing Record 22 of Set 13 | balclutha
# Processing Record 23 of Set 13 | tecoanapa
# Processing Record 24 of Set 13 | inirida
# Processing Record 25 of Set 13 | eyrarbakki
# Processing Record 26 of Set 13 | shubarshi
# Processing Record 27 of Set 13 | hami
# Processing Record 28 of Set 13 | sistranda
# Processing Record 29 of Set 13 | nedjo
# Processing Record 30 of Set 13 | dalian
# Processing Record 31 of Set 13 | whitianga
# Processing Record 32 of Set 13 | kununurra
# Processing Record 33 of Set 13 | malwan
# City was not found. Skipping...
# Processing Record 34 of Set 13 | mizpe ramon
# City was not found. Skipping...
# Processing Record 35 of Set 13 | gushikawa
# Processing Record 36 of Set 13 | darhan
# Processing Record 37 of Set 13 | mackay
# Processing Record 38 of Set 13 | zaykovo
# Processing Record 39 of Set 13 | solnechnyy
# Processing Record 40 of Set 13 | swan hill
# Processing Record 41 of Set 13 | macas
# Processing Record 42 of Set 13 | nalgonda
# Processing Record 43 of Set 13 | bajil
# Processing Record 44 of Set 13 | westport
# Processing Record 45 of Set 13 | shawville
# Processing Record 46 of Set 13 | dover
# Processing Record 47 of Set 13 | nhulunbuy
# Processing Record 48 of Set 13 | ostrovnoy
# Processing Record 49 of Set 13 | calabozo
# Processing Record 50 of Set 13 | lundazi
# ------------------------------------------------------------------
# Waiting 60 seconds...
# ------------------------------------------------------------------
# Processing Record 1 of Set 14 | galesong
# Processing Record 2 of Set 14 | vizinga
# Processing Record 3 of Set 14 | derzhavinsk
# Processing Record 4 of Set 14 | yashan
# Processing Record 5 of Set 14 | miyakonojo
# Processing Record 6 of Set 14 | nyaunglebin
# Processing Record 7 of Set 14 | trincomalee
# Processing Record 8 of Set 14 | fuyang
# Processing Record 9 of Set 14 | tongling
# Processing Record 10 of Set 14 | balaipungut
# Processing Record 11 of Set 14 | sinnamary
# Processing Record 12 of Set 14 | phalodi
# Processing Record 13 of Set 14 | aksaray
# Processing Record 14 of Set 14 | noyabrsk
# Processing Record 15 of Set 14 | maniitsoq
# Processing Record 16 of Set 14 | ola
# Processing Record 17 of Set 14 | libenge
# Processing Record 18 of Set 14 | napier
# Processing Record 19 of Set 14 | hirara
# Processing Record 20 of Set 14 | artigas
# Processing Record 21 of Set 14 | ahar
# Processing Record 22 of Set 14 | cayenne
# Processing Record 23 of Set 14 | ca mau
# Processing Record 24 of Set 14 | le vauclin
# Processing Record 25 of Set 14 | kutum
# Processing Record 26 of Set 14 | bandipur
# Processing Record 27 of Set 14 | mezen
# Processing Record 28 of Set 14 | arman
# Processing Record 29 of Set 14 | segezha
# Processing Record 30 of Set 14 | alakurtti
# Processing Record 31 of Set 14 | yar-sale
# Processing Record 32 of Set 14 | geresk
# City was not found. Skipping...
# Processing Record 33 of Set 14 | kalomo
# City was not found. Skipping...
# Processing Record 34 of Set 14 | pangai
# Processing Record 35 of Set 14 | gorno-chuyskiy
# City was not found. Skipping...
# Processing Record 36 of Set 14 | lima
# Processing Record 37 of Set 14 | sechura
# Processing Record 38 of Set 14 | pithoragarh
# Processing Record 39 of Set 14 | tagcatong
# Processing Record 40 of Set 14 | shakiso
# Processing Record 41 of Set 14 | krasnyy oktyabr
# Processing Record 42 of Set 14 | maghama
# City was not found. Skipping...
# Processing Record 43 of Set 14 | srednekolymsk
# Processing Record 44 of Set 14 | half moon bay
# Processing Record 45 of Set 14 | wanganui
# Processing Record 46 of Set 14 | kesennuma
# City was not found. Skipping...
# Processing Record 47 of Set 14 | labytnangi
# Processing Record 48 of Set 14 | royan
# Processing Record 49 of Set 14 | lhokseumawe
# Processing Record 50 of Set 14 | pedro carbo
# ------------------------------------------------------------------
# Waiting 60 seconds...
# ------------------------------------------------------------------
# Processing Record 1 of Set 15 | takaungu
# Processing Record 2 of Set 15 | machali
# Processing Record 3 of Set 15 | mokrousovo
# Processing Record 4 of Set 15 | athabasca
# Processing Record 5 of Set 15 | flinders
# Processing Record 6 of Set 15 | katangli
# Processing Record 7 of Set 15 | naze
# Processing Record 8 of Set 15 | simao
# Processing Record 9 of Set 15 | inhambane
# Processing Record 10 of Set 15 | margate
# Processing Record 11 of Set 15 | polunochnoye
# Processing Record 12 of Set 15 | escanaba
# Processing Record 13 of Set 15 | anshan
# Processing Record 14 of Set 15 | machico
# Processing Record 15 of Set 15 | dezhou
# Processing Record 16 of Set 15 | meyungs
# City was not found. Skipping...
# Processing Record 17 of Set 15 | muzhi
# Processing Record 18 of Set 15 | ulaangom
# Processing Record 19 of Set 15 | beyneu
# Processing Record 20 of Set 15 | aksarka
# Processing Record 21 of Set 15 | kilrush
# Processing Record 22 of Set 15 | khanpur
# Processing Record 23 of Set 15 | barra dos coqueiros
# Processing Record 24 of Set 15 | moranbah
# Processing Record 25 of Set 15 | pasighat
# Processing Record 26 of Set 15 | washington
# Processing Record 27 of Set 15 | tete
# Processing Record 28 of Set 15 | suez
# Processing Record 29 of Set 15 | totness
# Processing Record 30 of Set 15 | leshukonskoye
# Processing Record 31 of Set 15 | chateau-gontier
# Processing Record 32 of Set 15 | vila
# Processing Record 33 of Set 15 | grand centre
# City was not found. Skipping...
# Processing Record 34 of Set 15 | bengkalis
# City was not found. Skipping...
# Processing Record 35 of Set 15 | nelson bay
# Processing Record 36 of Set 15 | hjelset
# Processing Record 37 of Set 15 | nizhniy kuranakh
# Processing Record 38 of Set 15 | kathmandu
# Processing Record 39 of Set 15 | koslan
# Processing Record 40 of Set 15 | locri
# Processing Record 41 of Set 15 | maloshuyka
# City was not found. Skipping...
# Processing Record 42 of Set 15 | garden city
# Processing Record 43 of Set 15 | storforshei
# Processing Record 44 of Set 15 | canutama
# Processing Record 45 of Set 15 | imbituba
# Processing Record 46 of Set 15 | sesheke
# Processing Record 47 of Set 15 | alta floresta
# Processing Record 48 of Set 15 | tabialan
# City was not found. Skipping...
# Processing Record 49 of Set 15 | lerwick
# Processing Record 50 of Set 15 | tarimoro
# ------------------------------------------------------------------
# Waiting 60 seconds...
# ------------------------------------------------------------------
# Processing Record 1 of Set 16 | yulara
# Processing Record 2 of Set 16 | nuqui
# Processing Record 3 of Set 16 | arkansas city
# Processing Record 4 of Set 16 | san francisco
# Processing Record 5 of Set 16 | snasa
# Processing Record 6 of Set 16 | robertsport
# Processing Record 7 of Set 16 | thinadhoo
# Processing Record 8 of Set 16 | katobu
# Processing Record 9 of Set 16 | itacoatiara
# Processing Record 10 of Set 16 | marshfield
# Processing Record 11 of Set 16 | chara
# Processing Record 12 of Set 16 | karachi
# Processing Record 13 of Set 16 | rosarito
# Processing Record 14 of Set 16 | high level
# Processing Record 15 of Set 16 | rincon
# Processing Record 16 of Set 16 | aksay
# Processing Record 17 of Set 16 | mecca
# -----------------------------
# Data Retrieval Completed
# -----------------------------
# Total number of cities that were pulled via the API: 706

# %%
# Add the data to a new DataFrame, show first 10 to make sure the format match the required one
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     East London      ZA -33.0153   27.9116     54.88        63          86
# 1  Cabo San Lucas      MX  22.8909 -109.9124     88.90        74          40
# 2         Qaanaaq      GL  77.4840  -69.3632     40.32        88          98
# 3     Pangnirtung      CA  66.1451  -65.7125     42.30        93         100
# 4            Chuy      UY -33.6971  -53.4616     58.39        87           2
# 5  Ciudad Bolivar      VE   8.1222  -63.5497     78.69        82          79
# 6          Renqiu      CN  38.6989  116.0936     82.62        79          96
# 7     New Norfolk      AU -42.7826  147.0587     54.90        87          61
# 8       Hanstholm      DK  57.1167    8.6167     65.30        79         100
# 9          Bethel      US  41.3712  -73.4140     73.36        63           0
#
#    Wind Speed Current Description
# 0       29.37          light rain
# 1       11.50    scattered clouds
# 2        7.87     overcast clouds
# 3        2.71     overcast clouds
# 4        9.95           clear sky
# 5        2.44       broken clouds
# 6        3.33     overcast clouds
# 7        4.76       moderate rain
# 8       10.76     overcast clouds
# 9        0.00           clear sky

# %%
# Export DataFrame as a CSV file
# I will set Citi_ID as the index label so it gets as the column header
city_data_df.to_csv("WeatherPy_Database.csv", index_label="City_ID")
